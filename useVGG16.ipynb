# %% [markdown]
# <a href="https://colab.research.google.com/github/TatyanaPythonista/picture_recognizer_VGG16/blob/main/useVGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow import keras
from google.colab import files
from io import BytesIO
from PIL import Image
from tensorflow.python.keras.preprocessing import image as kp_image

# %%
model = keras.applications.VGG16()
# Out:
# ...
# 553467904/553467096 [==============================] - 4s 0us/step

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-350c6ad6-ad68-4af6-8295-aba2012c04be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-350c6ad6-ad68-4af6-8295-aba2012c04be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 280414.jpg to 280414.jpg

# %%
img = Image.open(BytesIO(uploaded['280414.jpg']))
plt.imshow(img)

# %%
img = np.array(img)
x = keras.applications.vgg16.preprocess_input(img)
print(x.shape)
x = np.expand_dims(x, axis=0)
print(x.shape)
# Out:
# (224, 224, 3)

# %%
result = model.predict(x)
print(np.argmax(result))
# Out:
# 671
